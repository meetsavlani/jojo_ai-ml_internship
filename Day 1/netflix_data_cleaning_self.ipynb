# %%
import pandas
import numpy

# %%
dataset = pandas.read_csv("netflix_titles.csv")
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8709 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int32
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int32(1), object(10)
# memory usage: 791.4+ KB

# %%
# convert date_added to datetime format
dataset["date_added"] = pandas.to_datetime(dataset["date_added"], errors="coerce")

# %%
dataset.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
dataset.shape
# Out:
# (8807, 12)

# %%
dataset.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# setting missing director, cast, country,  to unknown 
dataset["director"] = dataset["director"].fillna("Unknown")
dataset["cast"] = dataset["cast"].fillna("Unknown")
dataset["country"] = dataset["country"].fillna("Unknown")

# setting date added by forward fill method
dataset["date_added"] = dataset["date_added"].fillna(method="ffill")

# dropping missing values from rating
dataset = dataset.dropna(subset=["rating"])
# Out:
# C:\Users\Meet\AppData\Local\Temp\ipykernel_30404\1349205310.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset["date_added"] = dataset["date_added"].fillna(method="ffill")

# %%
# duplicate values
dataset.duplicated()
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset["rating"].unique()
dataset["listed_in"].unique()
# as we can see there are some data which should not be there in the column like 84 min 66 min etc. so we will replace these values with mode of rating values
dataset["rating"] = dataset["rating"].replace(
    ["84 min", "66 min", "74 min", "86 min", "90 min", "NR", "UR","nan"], dataset["rating"].mode()[0]
)

# %%
dataset["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'TV-Y7-FV'], dtype=object)

# %%
dataset["listed_in"].unique()
# Out:
# array(['Documentaries', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'Docuseries, Reality TV',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'TV Dramas, TV Horror, TV Mysteries', 'Children & Family Movies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'TV Comedies, TV Dramas', 'Documentaries, International Movies',
#        'Crime TV Shows, Spanish-Language TV Shows, TV Dramas',
#        'Thrillers',
#        'International TV Shows, Spanish-Language TV Shows, TV Action & Adventure',
#        'International TV Shows, TV Action & Adventure, TV Dramas',
# ...

# %% [markdown]
# what i did vs (what was supposed to be done !)
#
#
# 1. LOAD and Understand data (correctly done)
# 2. date(object) to datetime datatype change (correctly done)
# 3. checked for dupes (none)(correctly done)
# 4. director, cast, country unknown (correctly done)
# 5. date imputed (it was not supposed to be done as it does not changes or provides any extra meaning and also it is factually wrong)
# 6. replaced rating values of minutes and season,nr,ur with mode (instead i have checked unique values of ratings and swap them with the real rows , here data was correct and valid but just misplaced so swapped data from ratings and duration of that threee data )
# 7. not unified the ur nr values instead i added mode of the ratings which was wrong (i should have just unify nr ur not rated into not rated )
